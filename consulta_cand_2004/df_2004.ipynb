# %%
import pandas as pd

# %%
df_2004_AC = pd.read_csv(r'consulta_cand_2004_AC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_AL = pd.read_csv(r'consulta_cand_2004_AL.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_AM = pd.read_csv(r'consulta_cand_2004_AM.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_AP = pd.read_csv(r'consulta_cand_2004_AP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_BA = pd.read_csv(r'consulta_cand_2004_BA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_CE = pd.read_csv(r'consulta_cand_2004_CE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_ES = pd.read_csv(r'consulta_cand_2004_ES.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_GO = pd.read_csv(r'consulta_cand_2004_GO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_MA = pd.read_csv(r'consulta_cand_2004_MA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_MG = pd.read_csv(r'consulta_cand_2004_MG.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_MT = pd.read_csv(r'consulta_cand_2004_MT.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_MS = pd.read_csv(r'consulta_cand_2004_MS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_PA = pd.read_csv(r'consulta_cand_2004_PA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_PB = pd.read_csv(r'consulta_cand_2004_PB.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_PE = pd.read_csv(r'consulta_cand_2004_PE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_PI = pd.read_csv(r'consulta_cand_2004_PI.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_PR = pd.read_csv(r'consulta_cand_2004_PR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_RJ = pd.read_csv(r'consulta_cand_2004_RJ.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_RN = pd.read_csv(r'consulta_cand_2004_RN.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_RO = pd.read_csv(r'consulta_cand_2004_RO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_RR = pd.read_csv(r'consulta_cand_2004_RR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_RS = pd.read_csv(r'consulta_cand_2004_RS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_SC = pd.read_csv(r'consulta_cand_2004_SC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_SE = pd.read_csv(r'consulta_cand_2004_SE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_SP = pd.read_csv(r'consulta_cand_2004_SP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2004_TO = pd.read_csv(r'consulta_cand_2004_TO.txt', delimiter=';',
                         encoding='latin-1', header=None)

df_2004 = pd.concat([df_2004_AC, df_2004_AL, df_2004_AM, df_2004_AP, df_2004_BA, df_2004_CE,
                df_2004_ES, df_2004_GO, df_2004_MA, df_2004_MG, df_2004_MT, df_2004_MS,
                df_2004_PA, df_2004_PB, df_2004_PB, df_2004_PI, df_2004_PR, df_2004_RJ,
                df_2004_RN, df_2004_RO, df_2004_RR, df_2004_RS, df_2004_SC, df_2004_SE,
                df_2004_SP, df_2004_TO])
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (13,26,27,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (13,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2004.head().T
# Out:
#                                  0                              1  \
# 0                       08/10/2020                     08/10/2020
# 1                         12:14:27                       12:14:27
# 2                             2004                           2004
# 3                                1                              1
# 4                    ELEICOES 2004                  ELEICOES 2004
# 5                               AC                             AC
# 6                             1120                           1120
# 7                       ACRELANDIA                     ACRELANDIA
# 8                               11                             11
# 9                         PREFEITO                       PREFEITO
# 10  PAULO CÉSAR FERREIRA DE ARAUJO                JOÃO DE ALMEIDA
# 11                               1                              6
# 12                              14                             13
# ...

# %%
df_2004.columns = ['a1', 'b2', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO', 
                        'SG_UF', 'c7', 'NM_UE', 'd9', 'DS_CARGO', 'g11', 'h12', 'i13',
                        'j14', 'k15', 'l16', 'DS_DETALHE_SITUACAO_CAND', 'm17',
                        'SG_PARTIDO', 'n19', 'o20', 'p21', 'q22', 'r23', 's24', 't25',
                        'u26', 
                        'v27', 'x28','w29', 'DS_GENERO', 'y31', 'DS_GRAU_INSTRUCAO', 
                        'z33', 'a34','b35', 'c36', 'd37', 'e38', 'f39', 'g40', 'h41',
                        'DS_SIT_TOT_TURNO']

# %%
df_2004.head().T
# Out:
#                                                        0  \
# a1                                            08/10/2020
# b2                                              12:14:27
# ANO_ELEICAO                                         2004
# CD_TIPO_ELEICAO                                        1
# NM_TIPO_ELEICAO                            ELEICOES 2004
# SG_UF                                                 AC
# c7                                                  1120
# NM_UE                                         ACRELANDIA
# d9                                                    11
# DS_CARGO                                        PREFEITO
# g11                       PAULO CÉSAR FERREIRA DE ARAUJO
# h12                                                    1
# i13                                                   14
# j14                                          07857136204
# k15                                             PAULINHO
# ...

# %%
df_2004.to_csv('consulta_cand_2004_BRASIL.csv', index=False)

# %%
df_2004.to_csv('../consulta_cand_2004_BRASIL.csv', index=False)

# %%
df_2004['DS_CARGO'].unique()
# Out:
# array(['PREFEITO', 'VICE-PREFEITO', 'VEREADOR'], dtype=object)

# %%
df_2004['DS_GENERO'].unique()
# Out:
# array(['MASCULINO', 'FEMININO', 'NÃO INFORMADO'], dtype=object)

# %%
df_2004['DS_SIT_TOT_TURNO'].unique()
# Out:
# array(['NÃO ELEITO', 'ELEITO', '#NULO#', 'MÉDIA', 'SUPLENTE',
#        'RENÚNCIA/FALECIMENTO/CASSAÇÃO APÓS A ELEIÇÃO',
#        'REGISTRO NEGADO ANTES DA ELEIÇÃO',
#        'RENÚNCIA/FALECIMENTO/CASSAÇÃO ANTES DA ELEIÇÃO',
#        'RENÚNCIA/FALECIMENTO COM SUBSTITUIÇÃO', '2º TURNO',
#        'REGISTRO NEGADO APÓS A ELEIÇÃO', nan], dtype=object)
