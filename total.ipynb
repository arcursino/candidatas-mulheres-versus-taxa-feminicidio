# %%
#importando os módulos

import pandas as pd
import numpy as np
from scipy.stats import mode
low_memory=False

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
#Leitura do dataset utilizado na análise
df_2020_teste = pd.read_csv(r'consulta_cand_2020_BRASIL.csv',
                            delimiter=';', encoding='latin-1')
df_2018_teste = pd.read_csv(r'consulta_cand_2018_BRASIL.csv',
                            delimiter=';', encoding='latin-1')
df_2016_teste = pd.read_csv(r'consulta_cand_2016_BRASIL.csv',
                            delimiter=';', encoding='latin-1')
df_2014_teste = pd.read_csv(r'consulta_cand_2014_BRASIL.csv',
                            delimiter=';', encoding='latin-1')
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (20,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2018_teste.head().T
# Out:
#                                               0  \
# DT_GERACAO                           01/10/2020
# HH_GERACAO                             11:48:48
# ANO_ELEICAO                                2018
# CD_TIPO_ELEICAO                               2
# NM_TIPO_ELEICAO               ELEIÇÃO ORDINÁRIA
# ...                                         ...
# CD_SITUACAO_CANDIDATO_PLEITO                  2
# DS_SITUACAO_CANDIDATO_PLEITO           DEFERIDO
# CD_SITUACAO_CANDIDATO_URNA                    2
# DS_SITUACAO_CANDIDATO_URNA             DEFERIDO
# ST_CANDIDATO_INSERIDO_URNA                  SIM
#
#                                                               1  \
# DT_GERACAO                                           01/10/2020
# HH_GERACAO                                             11:48:48
# ANO_ELEICAO                                                2018
# CD_TIPO_ELEICAO                                               2
# ...

# %%
df_2018_teste['DS_SIT_TOT_TURNO'].unique()
# Out:
# array(['SUPLENTE', 'NÃO ELEITO', 'ELEITO POR QP', '#NULO#', 'ELEITO',
#        'ELEITO POR MÉDIA', '2º TURNO'], dtype=object)

# %%
#Leitura do dataset utilizado na análise
df_2020 = pd.read_csv(r'consulta_cand_2020_BRASIL.csv', delimiter=';', encoding='latin-1',
                      usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

df_2018 = pd.read_csv(r'consulta_cand_2018_BRASIL.csv', delimiter=';', encoding='latin-1',
                     usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

df_2016 = pd.read_csv(r'consulta_cand_2016_BRASIL.csv', delimiter=';', encoding='latin-1',
                     usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

df_2014 = pd.read_csv(r'consulta_cand_2014_BRASIL.csv', delimiter=';', encoding='latin-1',
                     usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

# %%
df_2020.columns
# Out:
# Index(['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO', 'SG_UF', 'NM_UE',
#        'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
#        'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'],
#       dtype='object')

# %%
df_2016.columns
# Out:
# Index(['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO', 'SG_UF', 'NM_UE',
#        'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
#        'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'],
#       dtype='object')

# %%
df_2014_2020 = pd.concat([df_2014, df_2016, df_2018, df_2020])

# %%
df_2014_2020.to_csv('consulta_cand_2014_2020_BRASIL.csv', index=False)

# %%
df_2014_2020.head().T
# Out:
#                                              0                  1  \
# ANO_ELEICAO                               2014               2014
# CD_TIPO_ELEICAO                              2                  2
# NM_TIPO_ELEICAO              ELEIÇÃO ORDINÁRIA  ELEIÇÃO ORDINÁRIA
# SG_UF                                       AP                 PB
# NM_UE                                    AMAPÁ            PARAÍBA
# DS_CARGO                            GOVERNADOR  DEPUTADO ESTADUAL
# DS_DETALHE_SITUACAO_CAND  DEFERIDO COM RECURSO           DEFERIDO
# SG_PARTIDO                                 PDT                PSB
# DS_GENERO                            MASCULINO          MASCULINO
# DS_GRAU_INSTRUCAO            SUPERIOR COMPLETO  SUPERIOR COMPLETO
# DS_SIT_TOT_TURNO                        ELEITO           SUPLENTE
#
#                                            2                  3  \
# ANO_ELEICAO                             2014               2014
# ...

# %%
df_2004_BR = pd.read_csv(r'consulta_cand_2004_BRASIL.csv', delimiter=',',
                         encoding='utf_8')
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2004_BR.head()
# Out:
#            a1        b2  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO SG_UF  \
# 0  08/10/2020  12:14:27         2004                1   ELEICOES 2004    AC
# 1  08/10/2020  12:14:27         2004                1   ELEICOES 2004    AC
# 2  08/10/2020  12:14:27         2004                1   ELEICOES 2004    AC
# 3  08/10/2020  12:14:27         2004                1   ELEICOES 2004    AC
# 4  08/10/2020  12:14:27         2004                1   ELEICOES 2004    AC
#
#      c7       NM_UE  d9       DS_CARGO  ... z33        a34  b35  \
# 0  1120  ACRELANDIA  11       PREFEITO  ...   3  CASADO(A)    1
# 1  1120  ACRELANDIA  11       PREFEITO  ...   3  CASADO(A)    1
# 2  1120  ACRELANDIA  11       PREFEITO  ...   3  CASADO(A)    1
# 3  1120  ACRELANDIA  12  VICE-PREFEITO  ...   3  CASADO(A)    1
# 4  1120  ACRELANDIA  12  VICE-PREFEITO  ...   5   VIÚVO(A)    1
#
#                c36 d37  e38                    f39     g40  h41  \
# ...

# %%
df_2006_BR = pd.read_csv(r'consulta_cand_2006_BRASIL.csv', delimiter=',',
                         encoding='utf_8')

# %%
df_2006_BR.head()
# Out:
#            a1        b2  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO SG_UF  \
# 0  19/10/2015  19:03:23         2006                1   ELEICOES 2006    AC
# 1  19/10/2015  19:03:23         2006                1   ELEICOES 2006    AC
# 2  19/10/2015  19:03:23         2006                1   ELEICOES 2006    AC
# 3  19/10/2015  19:03:23         2006                1   ELEICOES 2006    AC
# 4  19/10/2015  19:03:23         2006                1   ELEICOES 2006    AC
#
#    c7 NM_UE  d9    DS_CARGO  ... z33          a34  b35              c36 d37  \
# 0  AC  ACRE   3  GOVERNADOR  ...   3    CASADO(A)    1  BRASILEIRA NATA  SP
# 1  AC  ACRE   3  GOVERNADOR  ...   1  SOLTEIRO(A)    1  BRASILEIRA NATA  PB
# 2  AC  ACRE   3  GOVERNADOR  ...   3    CASADO(A)    1  BRASILEIRA NATA  AC
# 3  AC  ACRE   3  GOVERNADOR  ...   3    CASADO(A)    1  BRASILEIRA NATA  CE
# 4  AC  ACRE   3  GOVERNADOR  ...   3    CASADO(A)    1  BRASILEIRA NATA  RN
#
#    e38         f39        g40 h41 DS_SIT_TOT_TURNO
# ...

# %%
df_2004_BR = pd.read_csv(r'consulta_cand_2004_BRASIL.csv', delimiter=',',
                         encoding='utf_8',
                         usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

df_2006_BR = pd.read_csv(r'consulta_cand_2006_BRASIL.csv', delimiter=',',
                         encoding='utf_8', 
                         usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

df_2008_BR = pd.read_csv(r'consulta_cand_2008_BRASIL.csv', delimiter=',',
                         encoding='utf_8',
                         usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

df_2010_BR = pd.read_csv(r'consulta_cand_2010_BRASIL.csv', delimiter=',',
                         encoding='utf_8',
                         usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

df_2012_BR = pd.read_csv(r'consulta_cand_2012_BRASIL.csv', delimiter=',',
                         encoding='utf_8',
                         usecols=['ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
       'SG_UF', 'NM_UE', 'DS_CARGO', 'DS_DETALHE_SITUACAO_CAND', 'SG_PARTIDO', 'DS_GENERO',
       'DS_GRAU_INSTRUCAO', 'DS_SIT_TOT_TURNO'])

# %%
df_2004_2012 = pd.concat([df_2004_BR, df_2006_BR, df_2008_BR, df_2010_BR, df_2012_BR])

# %%
df_2004_2012.tail().T
# Out:
#                                                        479358  \
# ANO_ELEICAO                                              2012
# CD_TIPO_ELEICAO                                             1
# NM_TIPO_ELEICAO           ELEIÇÃO SUPLEMENTAR DE TAIPAS DO TO
# SG_UF                                                      TO
# NM_UE                                     TAIPAS DO TOCANTINS
# DS_CARGO                                        VICE-PREFEITO
# DS_DETALHE_SITUACAO_CAND                             DEFERIDO
# SG_PARTIDO                                                PDT
# DS_GENERO                                           MASCULINO
# DS_GRAU_INSTRUCAO                           SUPERIOR COMPLETO
# DS_SIT_TOT_TURNO                                       ELEITO
#
#                                                        479359  \
# ANO_ELEICAO                                              2012
# CD_TIPO_ELEICAO                                             1
# ...

# %%
df_2004_2012.head().T
# Out:
#                                                0                     1  \
# ANO_ELEICAO                                 2004                  2004
# CD_TIPO_ELEICAO                                1                     1
# NM_TIPO_ELEICAO                    ELEICOES 2004         ELEICOES 2004
# SG_UF                                         AC                    AC
# NM_UE                                 ACRELANDIA            ACRELANDIA
# DS_CARGO                                PREFEITO              PREFEITO
# DS_DETALHE_SITUACAO_CAND                DEFERIDO              DEFERIDO
# SG_PARTIDO                                   PTB                    PT
# DS_GENERO                              MASCULINO             MASCULINO
# DS_GRAU_INSTRUCAO         FUNDAMENTAL INCOMPLETO  FUNDAMENTAL COMPLETO
# DS_SIT_TOT_TURNO                      NÃO ELEITO            NÃO ELEITO
#
#                                           2                     3  \
# ...

# %%
df_2004_2012.to_csv('consulta_cand_2004_2012_BRASIL.csv', index=False)

# %%
data_2014_2020 = pd.read_csv(r'consulta_cand_2014_2020_BRASIL.csv', delimiter=',',
                             encoding='utf_8')

# %%
data_2004_2012 = pd.read_csv(r'consulta_cand_2004_2012_BRASIL.csv', delimiter=',',
                             encoding='utf_8')

# %%
data_2004_2012.head()
# Out:
#    ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO SG_UF       NM_UE  \
# 0         2004                1   ELEICOES 2004    AC  ACRELANDIA
# 1         2004                1   ELEICOES 2004    AC  ACRELANDIA
# 2         2004                1   ELEICOES 2004    AC  ACRELANDIA
# 3         2004                1   ELEICOES 2004    AC  ACRELANDIA
# 4         2004                1   ELEICOES 2004    AC  ACRELANDIA
#
#         DS_CARGO DS_DETALHE_SITUACAO_CAND SG_PARTIDO  DS_GENERO  \
# 0       PREFEITO                 DEFERIDO        PTB  MASCULINO
# 1       PREFEITO                 DEFERIDO         PT  MASCULINO
# 2       PREFEITO                 DEFERIDO       PSDB  MASCULINO
# 3  VICE-PREFEITO                 DEFERIDO       PMDB  MASCULINO
# 4  VICE-PREFEITO                 DEFERIDO        PTB  MASCULINO
#
#         DS_GRAU_INSTRUCAO DS_SIT_TOT_TURNO
# 0  FUNDAMENTAL INCOMPLETO       NÃO ELEITO
# 1    FUNDAMENTAL COMPLETO       NÃO ELEITO
# 2       SUPERIOR COMPLETO           ELEITO
# ...

# %%
df = pd.concat([data_2004_2012, data_2014_2020])

# %%
df.to_csv('consulta_cand_2004_2020_BRASIL.csv', index=False)

# %%
df.shape
# Out:
# (2407292, 11)

# %%
df['DS_CARGO'].unique()
# Out:
# array(['PREFEITO', 'VICE-PREFEITO', 'VEREADOR', 'GOVERNADOR',
#        'VICE-GOVERNADOR', 'SENADOR', 'DEPUTADO FEDERAL',
#        'DEPUTADO ESTADUAL', '1º SUPLENTE SENADOR', '2º SUPLENTE SENADOR',
#        'PRESIDENTE', 'VICE-PRESIDENTE',
#        'VOCÊ É A FAVOR | DA CRIAÇÃO DO MUNICÍPIO DE | EXTREMA DE RONDÔNIA?',
#        'VOCÊ É A FAVOR DA | ALTERAÇÃO DO NOME | DA CIDADE DE EMBU" | PARA "EMBU DAS ARTES"?"',
#        'DEPUTADO DISTRITAL', '1º SUPLENTE', '2º SUPLENTE'], dtype=object)

# %%
df['DS_GENERO'].unique()
# Out:
# array(['MASCULINO', 'FEMININO', 'NÃO INFORMADO', '6', '8',
#        'NÃO DIVULGÁVEL'], dtype=object)
