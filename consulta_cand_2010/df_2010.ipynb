# %%
import pandas as pd

# %%
df_2010_AC = pd.read_csv(r'consulta_cand_2010_AC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_AL = pd.read_csv(r'consulta_cand_2010_AL.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_AM = pd.read_csv(r'consulta_cand_2010_AM.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_AP = pd.read_csv(r'consulta_cand_2010_AP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_BA = pd.read_csv(r'consulta_cand_2010_BA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_CE = pd.read_csv(r'consulta_cand_2010_CE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_ES = pd.read_csv(r'consulta_cand_2010_ES.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_GO = pd.read_csv(r'consulta_cand_2010_GO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_MA = pd.read_csv(r'consulta_cand_2010_MA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_MG = pd.read_csv(r'consulta_cand_2010_MG.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_MT = pd.read_csv(r'consulta_cand_2010_MT.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_MS = pd.read_csv(r'consulta_cand_2010_MS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_PA = pd.read_csv(r'consulta_cand_2010_PA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_PB = pd.read_csv(r'consulta_cand_2010_PB.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_PE = pd.read_csv(r'consulta_cand_2010_PE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_PI = pd.read_csv(r'consulta_cand_2010_PI.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_PR = pd.read_csv(r'consulta_cand_2010_PR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_RJ = pd.read_csv(r'consulta_cand_2010_RJ.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_RN = pd.read_csv(r'consulta_cand_2010_RN.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_RO = pd.read_csv(r'consulta_cand_2010_RO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_RR = pd.read_csv(r'consulta_cand_2010_RR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_RS = pd.read_csv(r'consulta_cand_2010_RS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_SC = pd.read_csv(r'consulta_cand_2010_SC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_SE = pd.read_csv(r'consulta_cand_2010_SE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_SP = pd.read_csv(r'consulta_cand_2010_SP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_TO = pd.read_csv(r'consulta_cand_2010_TO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2010_BR = pd.read_csv(r'consulta_cand_2010_BR.txt', delimiter=';',
                         encoding='latin-1', header=None)

df_2010 = pd.concat([df_2010_AC, df_2010_AL, df_2010_AM, df_2010_AP, df_2010_BA, df_2010_CE,
                df_2010_ES, df_2010_GO, df_2010_MA, df_2010_MG, df_2010_MT, df_2010_MS,
                df_2010_PA, df_2010_PB, df_2010_PB, df_2010_PI, df_2010_PR, df_2010_RJ,
                df_2010_RN, df_2010_RO, df_2010_RR, df_2010_RS, df_2010_SC, df_2010_SE,
                df_2010_SP, df_2010_TO, df_2010_BR])

# %%
df_2010.head().T
# Out:
#                                            0  \
# 0                                 19/02/2016
# 1                                   19:56:33
# 2                                       2010
# 3                                          1
# 4                              ELEIÇÕES 2010
# 5                                         AC
# 6                                         AC
# 7                                       ACRE
# 8                                          3
# 9                                 GOVERNADOR
# 10                     ANTONIO NERES GOUVEIA
# 11                               10000000508
# 12                                        28
# 13                                3589994215
# 14                       GOUVEIA O TIJOLINHO
# 15                                         2
# 16                                  DEFERIDO
# 17                                        28
# 18                                      PRTB
# 19  PARTIDO RENOVADOR TRABALHISTA BRASILEIRO
# ...

# %%
df_2010.columns = ['a1', 'b2', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO', 
                        'SG_UF', 'c7', 'NM_UE', 'd9', 'DS_CARGO', 'g11', 'h12', 'i13',
                        'j14', 'k15', 'l16', 'DS_DETALHE_SITUACAO_CAND', 'm17',
                        'SG_PARTIDO', 'n19', 'o20', 'p21', 'q22', 'r23', 's24', 't25',
                        'u26', 
                        'v27', 'x28','w29', 'DS_GENERO', 'y31', 'DS_GRAU_INSTRUCAO', 
                        'z33', 'a34','b35', 'c36', 'd37', 'e38', 'f39', 'g40', 'h41',
                        'DS_SIT_TOT_TURNO']

# %%
df_2010.head().T
# Out:
#                                                                  0  \
# a1                                                      19/02/2016
# b2                                                        19:56:33
# ANO_ELEICAO                                                   2010
# CD_TIPO_ELEICAO                                                  1
# NM_TIPO_ELEICAO                                      ELEIÇÕES 2010
# SG_UF                                                           AC
# c7                                                              AC
# NM_UE                                                         ACRE
# d9                                                               3
# DS_CARGO                                                GOVERNADOR
# g11                                          ANTONIO NERES GOUVEIA
# h12                                                    10000000508
# i13                                                             28
# ...

# %%
df_2010.to_csv('consulta_cand_2010_BRASIL.csv', index=False)
df_2010.to_csv('../consulta_cand_2010_BRASIL.csv', index=False)

# %%
df_2010['DS_CARGO'].unique()
# Out:
# array(['GOVERNADOR', 'VICE-GOVERNADOR', 'SENADOR', 'DEPUTADO FEDERAL',
#        'DEPUTADO ESTADUAL', '1º SUPLENTE SENADOR', '2º SUPLENTE SENADOR',
#        'PRESIDENTE', 'VICE-PRESIDENTE'], dtype=object)

# %%
df_2010['DS_GENERO'].unique()
# Out:
# array(['MASCULINO', 'FEMININO'], dtype=object)

# %%
df_2010['DS_SIT_TOT_TURNO'].unique()
# Out:
# array(['NÃO ELEITO', 'ELEITO', '#NE#', 'SUPLENTE', 'MÉDIA',
#        'REGISTRO NEGADO ANTES DA ELEIÇÃO', 'CASSADO COM RECURSO',
#        '2º TURNO', 'RENÚNCIA/FALECIMENTO/CASSAÇÃO ANTES DA ELEIÇÃO',
#        'SUBSTITUÍDO', 'INDEFERIDO COM RECURSO',
#        'RENÚNCIA/FALECIMENTO/CASSAÇÃO APÓS A ELEIÇÃO',
#        'REGISTRO NEGADO APÓS A ELEIÇÃO'], dtype=object)

# %%
x = pd.DataFrame(df_2010.query('DS_CARGO == "PRESIDENTE" and DS_GENERO == "FEMININO" and DS_SIT_TOT_TURNO  == "ELEITO"'))
y = pd.DataFrame(df_2010.query('DS_CARGO == "PRESIDENTE" and DS_GENERO == "FEMININO" and DS_SIT_TOT_TURNO  == "NÃO ELEITO"'))

# %%
# Concatena os dataframes criados acima
data = pd.concat([x, y])

# %%
data.head()
# Out:
#             a1        b2  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO SG_UF  \
# 18  19/10/2015  19:03:29         2010                2   ELEIÇÕES 2010    BR
# 6   19/10/2015  19:03:29         2010                1   ELEIÇÕES 2010    BR
#
#     c7   NM_UE  d9    DS_CARGO  ... z33            a34  b35              c36  \
# 18  BR  BRASIL   1  PRESIDENTE  ...   9  DIVORCIADO(A)    1  BRASILEIRA NATA
# 6   BR  BRASIL   1  PRESIDENTE  ...   3      CASADO(A)    1  BRASILEIRA NATA
#
#    d37  e38             f39        g40 h41 DS_SIT_TOT_TURNO
# 18  MG   -1  BELO HORIZONTE  176000000   1           ELEITO
# 6   AC   -1      RIO BRANCO   90000000   4       NÃO ELEITO
#
# [2 rows x 43 columns]
