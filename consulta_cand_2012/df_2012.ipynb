# %%
import pandas as pd

# %%
df_2012_AC = pd.read_csv(r'consulta_cand_2012_AC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_AL = pd.read_csv(r'consulta_cand_2012_AL.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_AM = pd.read_csv(r'consulta_cand_2012_AM.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_AP = pd.read_csv(r'consulta_cand_2012_AP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_BA = pd.read_csv(r'consulta_cand_2012_BA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_CE = pd.read_csv(r'consulta_cand_2012_CE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_ES = pd.read_csv(r'consulta_cand_2012_ES.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_GO = pd.read_csv(r'consulta_cand_2012_GO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_MA = pd.read_csv(r'consulta_cand_2012_MA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_MG = pd.read_csv(r'consulta_cand_2012_MG.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_MT = pd.read_csv(r'consulta_cand_2012_MT.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_MS = pd.read_csv(r'consulta_cand_2012_MS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_PA = pd.read_csv(r'consulta_cand_2012_PA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_PB = pd.read_csv(r'consulta_cand_2012_PB.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_PE = pd.read_csv(r'consulta_cand_2012_PE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_PI = pd.read_csv(r'consulta_cand_2012_PI.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_PR = pd.read_csv(r'consulta_cand_2012_PR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_RJ = pd.read_csv(r'consulta_cand_2012_RJ.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_RN = pd.read_csv(r'consulta_cand_2012_RN.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_RO = pd.read_csv(r'consulta_cand_2012_RO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_RR = pd.read_csv(r'consulta_cand_2012_RR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_RS = pd.read_csv(r'consulta_cand_2012_RS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_SC = pd.read_csv(r'consulta_cand_2012_SC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_SE = pd.read_csv(r'consulta_cand_2012_SE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_SP = pd.read_csv(r'consulta_cand_2012_SP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2012_TO = pd.read_csv(r'consulta_cand_2012_TO.txt', delimiter=';',
                         encoding='latin-1', header=None)

df_2012 = pd.concat([df_2012_AC, df_2012_AL, df_2012_AM, df_2012_AP, df_2012_BA, df_2012_CE,
                df_2012_ES, df_2012_GO, df_2012_MA, df_2012_MG, df_2012_MT, df_2012_MS,
                df_2012_PA, df_2012_PB, df_2012_PB, df_2012_PI, df_2012_PR, df_2012_RJ,
                df_2012_RN, df_2012_RO, df_2012_RR, df_2012_RS, df_2012_SC, df_2012_SE,
                df_2012_SP, df_2012_TO])

# %%
df_2012.head().T
# Out:
#                                         0  \
# 0                              15/07/2016
# 1                                19:21:07
# 2                                    2012
# 3                                       1
# 4                  ELEIÇÃO MUNICIPAL 2012
# 5                                      AC
# 6                                    1015
# 7                                CAPIXABA
# 8                                      13
# 9                                VEREADOR
# 10            TEREZINHA FREIRES DE AMORIM
# 11                            10000002544
# 12                                  25010
# 13                            21755434200
# 14                              TEREZINHA
# 15                                      2
# 16                               DEFERIDO
# 17                                     25
# 18                                    DEM
# 19                             DEMOCRATAS
# 20                            10000000206
# ...

# %%
df_2012.columns = ['a1', 'b2', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO', 
                        'SG_UF', 'c7', 'NM_UE', 'd9', 'DS_CARGO', 'g11', 'h12', 'i13',
                        'j14', 'k15', 'l16', 'DS_DETALHE_SITUACAO_CAND', 'm17',
                        'SG_PARTIDO', 'n19', 'o20', 'p21', 'q22', 'r23', 's24', 't25',
                        'u26', 
                        'v27', 'x28','w29', 'DS_GENERO', 'y31', 'DS_GRAU_INSTRUCAO', 
                        'z33', 'a34','b35', 'c36', 'd37', 'e38', 'f39', 'g40', 'h41',
                        'DS_SIT_TOT_TURNO', 'i43']

# %%
df_2012.head().T
# Out:
#                                                               0  \
# a1                                                   15/07/2016
# b2                                                     19:21:07
# ANO_ELEICAO                                                2012
# CD_TIPO_ELEICAO                                               1
# NM_TIPO_ELEICAO                          ELEIÇÃO MUNICIPAL 2012
# SG_UF                                                        AC
# c7                                                         1015
# NM_UE                                                  CAPIXABA
# d9                                                           13
# DS_CARGO                                               VEREADOR
# g11                                 TEREZINHA FREIRES DE AMORIM
# h12                                                 10000002544
# i13                                                       25010
# j14                                                 21755434200
# ...

# %%
df_2012.to_csv('consulta_cand_2012_BRASIL.csv', index=False)

# %%
df_2012['DS_CARGO'].unique()
# Out:
# array(['VEREADOR', 'VICE-PREFEITO', 'PREFEITO'], dtype=object)

# %%
df_2012['DS_GENERO'].unique()
# Out:
# array(['FEMININO', 'MASCULINO'], dtype=object)

# %%
df_2012['DS_SIT_TOT_TURNO'].unique()
# Out:
# array(['NÃO ELEITO', 'ELEITO POR MÉDIA', 'SUPLENTE', 'ELEITO POR QP',
#        'ELEITO', '#NULO#', '2. TURNO'], dtype=object)
