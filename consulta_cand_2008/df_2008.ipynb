# %%
import pandas as pd

# %%
df_2008_AC = pd.read_csv(r'consulta_cand_2008_AC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_AL = pd.read_csv(r'consulta_cand_2008_AL.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_AM = pd.read_csv(r'consulta_cand_2008_AM.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_AP = pd.read_csv(r'consulta_cand_2008_AP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_BA = pd.read_csv(r'consulta_cand_2008_BA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_CE = pd.read_csv(r'consulta_cand_2008_CE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_ES = pd.read_csv(r'consulta_cand_2008_ES.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_GO = pd.read_csv(r'consulta_cand_2008_GO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_MA = pd.read_csv(r'consulta_cand_2008_MA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_MG = pd.read_csv(r'consulta_cand_2008_MG.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_MT = pd.read_csv(r'consulta_cand_2008_MT.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_MS = pd.read_csv(r'consulta_cand_2008_MS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_PA = pd.read_csv(r'consulta_cand_2008_PA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_PB = pd.read_csv(r'consulta_cand_2008_PB.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_PE = pd.read_csv(r'consulta_cand_2008_PE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_PI = pd.read_csv(r'consulta_cand_2008_PI.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_PR = pd.read_csv(r'consulta_cand_2008_PR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_RJ = pd.read_csv(r'consulta_cand_2008_RJ.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_RN = pd.read_csv(r'consulta_cand_2008_RN.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_RO = pd.read_csv(r'consulta_cand_2008_RO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_RR = pd.read_csv(r'consulta_cand_2008_RR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_RS = pd.read_csv(r'consulta_cand_2008_RS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_SC = pd.read_csv(r'consulta_cand_2008_SC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_SE = pd.read_csv(r'consulta_cand_2008_SE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_SP = pd.read_csv(r'consulta_cand_2008_SP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2008_TO = pd.read_csv(r'consulta_cand_2008_TO.txt', delimiter=';',
                         encoding='latin-1', header=None)

df_2008 = pd.concat([df_2008_AC, df_2008_AL, df_2008_AM, df_2008_AP, df_2008_BA, df_2008_CE,
                df_2008_ES, df_2008_GO, df_2008_MA, df_2008_MG, df_2008_MT, df_2008_MS,
                df_2008_PA, df_2008_PB, df_2008_PB, df_2008_PI, df_2008_PR, df_2008_RJ,
                df_2008_RN, df_2008_RO, df_2008_RR, df_2008_RS, df_2008_SC, df_2008_SE,
                df_2008_SP, df_2008_TO])
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (15,17,20,24,29,31,33,35,38,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (13,15,17,20,24,29,31,33,35,38,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2008.head().T
# Out:
#                                  0                              1  \
# 0                       08/10/2020                     08/10/2020
# 1                         12:14:27                       12:14:27
# 2                             2004                           2004
# 3                                1                              1
# 4                    ELEICOES 2004                  ELEICOES 2004
# 5                               AC                             AC
# 6                             1120                           1120
# 7                       ACRELANDIA                     ACRELANDIA
# 8                               11                             11
# 9                         PREFEITO                       PREFEITO
# 10  PAULO CÉSAR FERREIRA DE ARAUJO                JOÃO DE ALMEIDA
# 11                               1                              6
# 12                              14                             13
# ...

# %%
df_2008.columns = ['a1', 'b2', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO', 
                        'SG_UF', 'c7', 'NM_UE', 'd9', 'DS_CARGO', 'g11', 'h12', 'i13',
                        'j14', 'k15', 'l16', 'DS_DETALHE_SITUACAO_CAND', 'm17',
                        'SG_PARTIDO', 'n19', 'o20', 'p21', 'q22', 'r23', 's24', 't25',
                        'u26', 
                        'v27', 'x28','w29', 'DS_GENERO', 'y31', 'DS_GRAU_INSTRUCAO', 
                        'z33', 'a34','b35', 'c36', 'd37', 'e38', 'f39', 'g40', 'h41',
                        'DS_SIT_TOT_TURNO']

# %%
df_2008.head().T
# Out:
#                                                         0  \
# a1                                             06/10/2020
# b2                                               14:48:12
# ANO_ELEICAO                                          2008
# CD_TIPO_ELEICAO                                         1
# NM_TIPO_ELEICAO               Eleições Suplementares 2008
# SG_UF                                                  AC
# c7                                                   1139
# NM_UE                                               FEIJÓ
# d9                                                     11
# DS_CARGO                                         PREFEITO
# g11                            JACIARA DE SOUSA RODRIGUES
# h12                                                  1703
# i13                                                    13
# j14                                           76549410215
# k15                                               JACIARA
# ...

# %%
df_2008.to_csv('consulta_cand_2008_BRASIL.csv', index=False)

# %%
df_2008['DS_CARGO'].unique()
# Out:
# array(['PREFEITO', 'VICE-PREFEITO', 'VEREADOR',
#        'VOCÊ É A FAVOR | DA CRIAÇÃO DO MUNICÍPIO DE | EXTREMA DE RONDÔNIA?',
#        'VOCÊ É A FAVOR DA | ALTERAÇÃO DO NOME | DA CIDADE DE EMBU" | PARA "EMBU DAS ARTES"?"'],
#       dtype=object)

# %%
df_2008['DS_GENERO'].unique()
# Out:
# array(['FEMININO', 'MASCULINO', '6', '8'], dtype=object)

# %%
df_2008['DS_SIT_TOT_TURNO'].unique()
# Out:
# array(['NÃO ELEITO', 'ELEITO', '#NULO#', 'SUPLENTE', 'MÉDIA',
#        'INDEFERIDO COM RECURSO', 'REGISTRO NEGADO ANTES DA ELEIÇÃO',
#        'RENÚNCIA/FALECIMENTO/CASSAÇÃO ANTES DA ELEIÇÃO', 'SUBSTITUÍDO',
#        'REGISTRO NEGADO APÓS A ELEIÇÃO', '2º TURNO',
#        'RENÚNCIA/FALECIMENTO/CASSAÇÃO APÓS A ELEIÇÃO', nan], dtype=object)
