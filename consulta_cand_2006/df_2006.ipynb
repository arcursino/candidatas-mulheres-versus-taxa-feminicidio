# %%
import pandas as pd

# %%
df_2006_AC = pd.read_csv(r'consulta_cand_2006_AC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_AL = pd.read_csv(r'consulta_cand_2006_AL.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_AM = pd.read_csv(r'consulta_cand_2006_AM.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_AP = pd.read_csv(r'consulta_cand_2006_AP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_BA = pd.read_csv(r'consulta_cand_2006_BA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_CE = pd.read_csv(r'consulta_cand_2006_CE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_ES = pd.read_csv(r'consulta_cand_2006_ES.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_GO = pd.read_csv(r'consulta_cand_2006_GO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_MA = pd.read_csv(r'consulta_cand_2006_MA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_MG = pd.read_csv(r'consulta_cand_2006_MG.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_MT = pd.read_csv(r'consulta_cand_2006_MT.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_MS = pd.read_csv(r'consulta_cand_2006_MS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_PA = pd.read_csv(r'consulta_cand_2006_PA.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_PB = pd.read_csv(r'consulta_cand_2006_PB.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_PE = pd.read_csv(r'consulta_cand_2006_PE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_PI = pd.read_csv(r'consulta_cand_2006_PI.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_PR = pd.read_csv(r'consulta_cand_2006_PR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_RJ = pd.read_csv(r'consulta_cand_2006_RJ.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_RN = pd.read_csv(r'consulta_cand_2006_RN.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_RO = pd.read_csv(r'consulta_cand_2006_RO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_RR = pd.read_csv(r'consulta_cand_2006_RR.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_RS = pd.read_csv(r'consulta_cand_2006_RS.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_SC = pd.read_csv(r'consulta_cand_2006_SC.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_SE = pd.read_csv(r'consulta_cand_2006_SE.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_SP = pd.read_csv(r'consulta_cand_2006_SP.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_TO = pd.read_csv(r'consulta_cand_2006_TO.txt', delimiter=';',
                         encoding='latin-1', header=None)
df_2006_BR = pd.read_csv(r'consulta_cand_2006_BR.txt', delimiter=';',
                         encoding='latin-1', header=None)

df_2006 = pd.concat([df_2006_AC, df_2006_AL, df_2006_AM, df_2006_AP, df_2006_BA, df_2006_CE,
                df_2006_ES, df_2006_GO, df_2006_MA, df_2006_MG, df_2006_MT, df_2006_MS,
                df_2006_PA, df_2006_PB, df_2006_PB, df_2006_PI, df_2006_PR, df_2006_RJ,
                df_2006_RN, df_2006_RO, df_2006_RR, df_2006_RS, df_2006_SC, df_2006_SE,
                df_2006_SP, df_2006_TO, df_2006_BR])

# %%
df_2006_AL.tail().T
# Out:
#                                     391                               392  \
# 0                            19/10/2015                        19/10/2015
# 1                              19:03:23                          19:03:23
# 2                                  2006                              2006
# 3                                     1                                 1
# 4                         ELEICOES 2006                     ELEICOES 2006
# 5                                    AL                                AL
# 6                                    AL                                AL
# 7                               ALAGOAS                           ALAGOAS
# 8                                    10                                10
# 9                   2º SUPLENTE SENADOR               2º SUPLENTE SENADOR
# 10  ARNALDO PINTO GUEDES DE PAIVA FILHO           EVERALDO PEDRO DA SILVA
# 11                                10173                             10521
# ...

# %%
df_2006.head().T
# Out:
#                                     0                                 1  \
# 0                          19/10/2015                        19/10/2015
# 1                            19:03:23                          19:03:23
# 2                                2006                              2006
# 3                                   1                                 1
# 4                       ELEICOES 2006                     ELEICOES 2006
# 5                                  AC                                AC
# 6                                  AC                                AC
# 7                                ACRE                              ACRE
# 8                                   3                                 3
# 9                          GOVERNADOR                        GOVERNADOR
# 10  ARNÓBIO MARQUES DE ALMEIDA JUNIOR                   EDIVALDO GUEDES
# 11                              10027                             10422
# ...

# %%
df_2006.columns = ['a1', 'b2', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO', 
                        'SG_UF', 'c7', 'NM_UE', 'd9', 'DS_CARGO', 'g11', 'h12', 'i13',
                        'j14', 'k15', 'l16', 'DS_DETALHE_SITUACAO_CAND', 'm17',
                        'SG_PARTIDO', 'n19', 'o20', 'p21', 'q22', 'r23', 's24', 't25',
                        'u26', 
                        'v27', 'x28','w29', 'DS_GENERO', 'y31', 'DS_GRAU_INSTRUCAO', 
                        'z33', 'a34','b35', 'c36', 'd37', 'e38', 'f39', 'g40', 'h41',
                        'DS_SIT_TOT_TURNO']

# %%
df_2006.head().T
# Out:
#                                                           0  \
# a1                                               19/10/2015
# b2                                                 19:03:23
# ANO_ELEICAO                                            2006
# CD_TIPO_ELEICAO                                           1
# NM_TIPO_ELEICAO                               ELEICOES 2006
# SG_UF                                                    AC
# c7                                                       AC
# NM_UE                                                  ACRE
# d9                                                        3
# DS_CARGO                                         GOVERNADOR
# g11                       ARNÓBIO MARQUES DE ALMEIDA JUNIOR
# h12                                                   10027
# i13                                                      13
# j14                                             18313850230
# k15                                           BINHO MARQUES
# ...

# %%
df_2006.to_csv('consulta_cand_2006_BRASIL.csv', index=False)
df_2006.to_csv('../consulta_cand_2006_BRASIL.csv', index=False)

# %%
df_2006['DS_CARGO'].unique()
# Out:
# array(['GOVERNADOR', 'VICE-GOVERNADOR', 'SENADOR', 'DEPUTADO FEDERAL',
#        'DEPUTADO ESTADUAL', '1º SUPLENTE SENADOR', '2º SUPLENTE SENADOR',
#        'PRESIDENTE', 'VICE-PRESIDENTE'], dtype=object)

# %%
df_2006['DS_GENERO'].unique()
# Out:
# array(['MASCULINO', 'FEMININO'], dtype=object)

# %%
df_2006['DS_SIT_TOT_TURNO'].unique()
# Out:
# array(['ELEITO', 'NÃO ELEITO', '#NE#', 'REGISTRO NEGADO ANTES DA ELEIÇÃO',
#        'SUPLENTE', 'MÉDIA',
#        'RENÚNCIA/FALECIMENTO/CASSAÇÃO ANTES DA ELEIÇÃO',
#        'REGISTRO NEGADO APÓS A ELEIÇÃO', '2º TURNO',
#        'RENÚNCIA/FALECIMENTO/CASSAÇÃO APÓS A ELEIÇÃO',
#        'RENÚNCIA/FALECIMENTO COM SUBSTITUIÇÃO'], dtype=object)

# %%
x = pd.DataFrame(df_2006.query('DS_CARGO == "PRESIDENTE" and DS_GENERO == "FEMININO" and DS_SIT_TOT_TURNO  == "ELEITO"'))
y = pd.DataFrame(df_2006.query('DS_CARGO == "PRESIDENTE" and DS_GENERO == "FEMININO" and DS_SIT_TOT_TURNO  == "NÃO ELEITO"'))

# %%
# Concatena os dataframes criados acima
data = pd.concat([x, y])

# %%
data.head()
# Out:
#            a1        b2  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO SG_UF  \
# 0  08/05/2017  16:18:43         2006                1   ELEICOES 2006    BR
# 3  08/05/2017  16:18:43         2006                1   ELEICOES 2006    BR
#
#    c7   NM_UE  d9    DS_CARGO  ... z33                        a34  b35  \
# 0  BR  BRASIL   1  PRESIDENTE  ...   9              DIVORCIADO(A)    1
# 3  BR  BRASIL   1  PRESIDENTE  ...   7  SEPARADO(A) JUDICIALMENTE    1
#
#                c36 d37  e38             f39          g40 h41 DS_SIT_TOT_TURNO
# 0  BRASILEIRA NATA  RJ   -1  RIO DE JANEIRO  150000000.0   4       NÃO ELEITO
# 3  BRASILEIRA NATA  AL   -1   PÃO DE AÇÚCAR    5000000.0   4       NÃO ELEITO
#
# [2 rows x 43 columns]

# %%
sit_ano = pd.crosstab(data['ANO_ELEICAO'],data['DS_SIT_TOT_TURNO'])
sit_ano
# Out:
# DS_SIT_TOT_TURNO  NÃO ELEITO
# ANO_ELEICAO
# 2006                       2

# %%
df_2006['DS_CARGO'].unique()
# Out:
# array(['GOVERNADOR', 'VICE-GOVERNADOR', 'SENADOR', 'DEPUTADO FEDERAL',
#        'DEPUTADO ESTADUAL', '1º SUPLENTE SENADOR', '2º SUPLENTE SENADOR',
#        'PRESIDENTE', 'VICE-PRESIDENTE'], dtype=object)
